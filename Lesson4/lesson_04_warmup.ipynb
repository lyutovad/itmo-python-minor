# %% [markdown]
# # Разминка перед занятием 4
#
# Вчера мы закончили базовый Python и дошли в NumPy до логических масок.
#
# **Сначала отвечаем без запуска кода, затем проверяем.**
#
# Ориентир: **10–15 минут**.

# %% [markdown]
# ## 1. Метод или атрибут?
#
# Для массива NumPy:
#
# ```python
# values.shape
# values.mean()
# ```
#
# Что из этого является атрибутом, а что методом? Как это определить по записи?

# %% [markdown]
# ## 2. Список и NumPy-массив
#
# Что будет выведено?
#
# ```python
# print([10, 20, 30] * 2)
#
# values = np.array([10, 20, 30])
# print(values * 2)
# ```
#
# Почему результаты различаются?

# %%
import numpy as np

# Запустите после обсуждения.
# print([10, 20, 30] * 2)
# values = np.array([10, 20, 30])
# print(values * 2)

# %% [markdown]
# ## 3. `shape`, `dtype`, `size`
#
# Дан массив:
#
# ```python
# scores = np.array([67, 82, 51, 90, 73])
# ```
#
# Не запуская код, предположите:
#
# - чему равен `scores.shape`;
# - чему равен `scores.size`;
# - какого типа элементы массива.

# %%
scores = np.array([67, 82, 51, 90, 73])

# print(scores.shape)
# print(scores.size)
# print(scores.dtype)

# %% [markdown]
# ## 4. Индексы и срезы
#
# Что получится?
#
# ```python
# values = np.array([10, 20, 30, 40, 50])
#
# print(values[0])
# print(values[-1])
# print(values[1:4])
# ```

# %% [markdown]
# ## 5. Векторная операция
#
# Что находится в `result`?
#
# ```python
# prices = np.array([100, 200, 300])
# result = prices * 1.2
# ```
#
# Изменился ли исходный `prices`?

# %%
prices = np.array([100, 200, 300])

# result = prices * 1.2
# print(prices)
# print(result)

# %% [markdown]
# ## 6. Что такое маска?
#
# Что будет содержать `mask`?
#
# ```python
# scores = np.array([45, 67, 82, 51, 90])
# mask = scores >= 60
# ```
#
# Какой тип значений будет внутри массива `mask`?

# %%
scores = np.array([45, 67, 82, 51, 90])

# mask = scores >= 60
# print(mask)

# %% [markdown]
# ## 7. Фильтрация по маске
#
# Что будет выведено?
#
# ```python
# scores = np.array([45, 67, 82, 51, 90])
# print(scores[scores >= 60])
# ```
#
# Попробуйте объяснить запись по частям:
#
# ```text
# scores
# scores >= 60
# scores[ ... ]
# ```

# %% [markdown]
# ## 8. Связь с обычным Python
#
# Что делает этот код?
#
# ```python
# numbers = [45, 67, 82, 51, 90]
# result = []
#
# for number in numbers:
#     if number >= 60:
#         result.append(number)
# ```
#
# Какая NumPy-запись выражает ту же идею короче?

# %%
numbers = [45, 67, 82, 51, 90]

# values = np.array(numbers)
# ...

# %% [markdown]
# ## 9. `try/except` — короткое повторение
#
# Что вернёт функция для `"1500"` и для `"нет данных"`?
#
# ```python
# def parse_amount(value):
#     try:
#         return float(value)
#     except ValueError:
#         return None
# ```

# %% [markdown]
# ## 10. Объектная модель
#
# В коде:
#
# ```python
# values = np.array([10, 20, 30])
#
# values.shape
# values.mean()
# ```
#
# что является объектом, атрибутом и методом?
#
# Эта же модель сейчас перейдёт в Pandas.

# %% [markdown]
# # Lesson 5 — Warm-up

# %% [markdown]
# ## Исходные данные
#
# ```python
# import pandas as pd
#
# df = pd.DataFrame({
#     "name": ["Анна", "Иван", "Ольга", "Пётр", "Мария"],
#     "city": [" Москва ", "Казань", "москва", " Томск", "КАЗАНЬ "],
#     "age": [25, 17, 31, 44, 28],
#     "amount": [1200, 700, 1800, 2300, 3100],
#     "status": ["paid", "paid", "cancelled", "paid", "paid"],
# })
# ```
#
# Сначала запустите ячейку с данными.

# %%
import pandas as pd

df = pd.DataFrame({
    "name": ["Анна", "Иван", "Ольга", "Пётр", "Мария"],
    "city": [" Москва ", "Казань", "москва", " Томск", "КАЗАНЬ "],
    "age": [25, 17, 31, 44, 28],
    "amount": [1200, 700, 1800, 2300, 3100],
    "status": ["paid", "paid", "cancelled", "paid", "paid"],
})

df

# %% [markdown]
# ## 1. Маска
#
# Что будет находиться в переменной `mask`?
#
# ```python
# mask = df["age"] >= 18
# ```
#
# Сначала ответьте словами, затем проверьте кодом.

# %%
# mask = ...
# mask

# %% [markdown]
# ## 2. Фильтрация по нескольким условиям
#
# Получите только строки, где одновременно:
#
# - `status == "paid"`;
# - `amount > 1000`.
#
# Используйте логическую маску.

# %%
# TODO

# %% [markdown]
# ## 3. Сортировка
#
# Отсортируйте таблицу по `amount` по убыванию.
#
# Ответьте:
#
# - изменился ли исходный `df`;
# - как сохранить отсортированный результат в отдельную переменную?

# %%
# TODO

# %% [markdown]
# ## 4. Новый столбец
#
# Создайте столбец `amount_with_tax`, равный `amount * 1.2`.
#
# Выведите только столбцы `amount` и `amount_with_tax`.

# %%
# TODO

# %% [markdown]
# ## 5. Строковые методы
#
# В `city` есть лишние пробелы и разный регистр.
#
# Создайте новый столбец `city_clean`, в котором:
#
# - убраны пробелы по краям;
# - все значения приведены к нижнему регистру.

# %%
# TODO

# %% [markdown]
# ## 6. Небольшая связная задача
#
# После создания `city_clean` получите таблицу:
#
# - только для Москвы и Казани;
# - только для оплаченных заказов;
# - оставить столбцы `name`, `city_clean`, `amount`;
# - отсортировать по `amount` по убыванию.
#
# Сохраните результат в `df_result`.

# %%
# TODO

# %% [markdown]
# ## Быстрая самопроверка
#
# Перед переходом к графикам убедитесь, что вы можете словами объяснить:
#
# 1. Что возвращает сравнение `df["amount"] > 1000`?
# 2. Почему для нескольких условий в Pandas используются `&` и `|`?
# 3. Чем фильтрация отличается от сортировки?
# 4. Что происходит при записи `df["new_column"] = ...`?
# 5. Зачем для строкового столбца используется `.str`?

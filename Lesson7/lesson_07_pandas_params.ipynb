# %% [markdown]
# ### Настройки вывода
#
# [Pandas docs](https://pandas.pydata.org/pandas-docs/stable/user_guide/options.html)

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/MyDrive/itmo_ai_minor_2026(autumn)/Lesson7/data/water_potability.csv')

# %%
df.head(100)
# Out:
#            ph    Hardness        Solids  Chloramines     Sulfate  \
# 0         NaN  204.890455  20791.318981     7.300212  368.516441
# 1    3.716080  129.422921  18630.057858     6.635246         NaN
# 2    8.099124  224.236259  19909.541732     9.275884         NaN
# 3    8.316766  214.373394  22018.417441     8.059332  356.886136
# 4    9.092223  181.101509  17978.986339     6.546600  310.135738
# 5    5.584087  188.313324  28748.687739     7.544869  326.678363
# 6   10.223862  248.071735  28749.716544     7.513408  393.663396
# 7    8.635849  203.361523  13672.091764     4.563009  303.309771
# 8         NaN  118.988579  14285.583854     7.804174  268.646941
# 9   11.180284  227.231469  25484.508491     9.077200  404.041635
# 10   7.360640  165.520797  32452.614409     7.550701  326.624353
# 11   7.974522  218.693300  18767.656682     8.110385         NaN
# 12   7.119824  156.704993  18730.813653     3.606036  282.344050
# ...

# %%
pd.options.display.max_rows
# Out:
# 60

# %%
pd.options.display.max_rows = 100

pd.options.display.max_rows
# Out:
# 100

# %%
df.head(10)
# Out:
#           ph    Hardness        Solids  Chloramines     Sulfate  Conductivity  \
# 0        NaN  204.890455  20791.318981     7.300212  368.516441    564.308654
# 1   3.716080  129.422921  18630.057858     6.635246         NaN    592.885359
# 2   8.099124  224.236259  19909.541732     9.275884         NaN    418.606213
# 3   8.316766  214.373394  22018.417441     8.059332  356.886136    363.266516
# 4   9.092223  181.101509  17978.986339     6.546600  310.135738    398.410813
# 5   5.584087  188.313324  28748.687739     7.544869  326.678363    280.467916
# 6  10.223862  248.071735  28749.716544     7.513408  393.663396    283.651634
# 7   8.635849  203.361523  13672.091764     4.563009  303.309771    474.607645
# 8        NaN  118.988579  14285.583854     7.804174  268.646941    389.375566
# 9  11.180284  227.231469  25484.508491     9.077200  404.041635    563.885481
#
#    Organic_carbon  Trihalomethanes  Turbidity  Potability
# ...

# %%
pd.set_option("max_colwidth", 10)

# %%
df
# Out:
#             ph   Hardness     Solids  Chloramines    Sulfate  Conductivity  \
# 0          NaN  204.89...  20791....   7.300212    368.51...  564.30...
# 1     3.716080  129.42...  18630....   6.635246          NaN  592.88...
# 2     8.099124  224.23...  19909....   9.275884          NaN  418.60...
# 3     8.316766  214.37...  22018....   8.059332    356.88...  363.26...
# 4     9.092223  181.10...  17978....   6.546600    310.13...  398.41...
# ...        ...        ...        ...        ...          ...        ...
# 3271  4.668102  193.68...  47580....   7.166639    359.94...  526.42...
# 3272  7.808856  193.55...  17329....   8.061362          NaN  392.44...
# 3273  9.419510  175.76...  33155....   7.350233          NaN  432.04...
# 3274  5.126763  230.60...  11983....   6.303357          NaN  402.88...
# 3275  7.874671  195.10...  17404....   7.509306          NaN  327.45...
#
#       Organic_carbon  Trihalomethanes  Turbidity  Potability
# ...

# %%
# pd.describe_option()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3276 entries, 0 to 3275
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ph               2785 non-null   float64
#  1   Hardness         3276 non-null   float64
#  2   Solids           3276 non-null   float64
#  3   Chloramines      3276 non-null   float64
#  4   Sulfate          2495 non-null   float64
#  5   Conductivity     3276 non-null   float64
#  6   Organic_carbon   3276 non-null   float64
#  7   Trihalomethanes  3114 non-null   float64
#  8   Turbidity        3276 non-null   float64
#  9   Potability       3276 non-null   int64
# dtypes: float64(9), int64(1)
# memory usage: 256.1 KB

# %%
display_settings = {
    'max_columns': 10,
    'colheader_justify': 'left',
    'large_repr': 'info'
}

for op, value in display_settings.items():
    pd.set_option(f"display.{op}", value)

# %%
# display_settings.items()

# %%
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3276 entries, 0 to 3275
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ph               2785 non-null   float64
#  1   Hardness         3276 non-null   float64
#  2   Solids           3276 non-null   float64
#  3   Chloramines      3276 non-null   float64
#  4   Sulfate          2495 non-null   float64
#  5   Conductivity     3276 non-null   float64
#  6   Organic_carbon   3276 non-null   float64
#  7   Trihalomethanes  3114 non-null   float64
#  8   Turbidity        3276 non-null   float64
#  9   Potability       3276 non-null   int64
# dtypes: float64(9), int64(1)
# memory usage: 256.1 KB

# %%
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ph               4 non-null      float64
#  1   Hardness         5 non-null      float64
#  2   Solids           5 non-null      float64
#  3   Chloramines      5 non-null      float64
#  4   Sulfate          3 non-null      float64
#  5   Conductivity     5 non-null      float64
#  6   Organic_carbon   5 non-null      float64
#  7   Trihalomethanes  5 non-null      float64
#  8   Turbidity        5 non-null      float64
#  9   Potability       5 non-null      int64
# dtypes: float64(9), int64(1)
# memory usage: 532.0 bytes

# %%
pd.reset_option('large_repr')

# %%
df
# Out:
#       ph        Hardness   Solids     Chloramines  Sulfate    Conductivity  \
# 0          NaN  204.89...  20791....  7.300212     368.51...  564.30...
# 1     3.716080  129.42...  18630....  6.635246           NaN  592.88...
# 2     8.099124  224.23...  19909....  9.275884           NaN  418.60...
# 3     8.316766  214.37...  22018....  8.059332     356.88...  363.26...
# 4     9.092223  181.10...  17978....  6.546600     310.13...  398.41...
# ...        ...        ...        ...        ...          ...        ...
# 3271  4.668102  193.68...  47580....  7.166639     359.94...  526.42...
# 3272  7.808856  193.55...  17329....  8.061362           NaN  392.44...
# 3273  9.419510  175.76...  33155....  7.350233           NaN  432.04...
# 3274  5.126763  230.60...  11983....  6.303357           NaN  402.88...
# 3275  7.874671  195.10...  17404....  7.509306           NaN  327.45...
#
#       Organic_carbon  Trihalomethanes  Turbidity  Potability
# ...

# %%
pd.options.display.max_info_columns
# Out:
# 100

# %%
# # pandas
# pd.set_option("display.max_columns", None)      # показывать все столбцы
# pd.set_option("display.max_rows", 100)          # сколько строк максимум показывать
# pd.set_option("display.width", 1200)            # ширина вывода
# pd.set_option("display.max_colwidth", 200)      # ширина текста в ячейке
# pd.set_option("display.float_format", "{:.2f}".format)  # формат float

# # matplotlib
# plt.rcParams["figure.figsize"] = (8, 5)         # размер графиков по умолчанию
# plt.rcParams["figure.dpi"] = 120                # качество
# plt.rcParams["font.size"] = 11                  # размер шрифта
# plt.rcParams["axes.titlesize"] = 13             # заголовок графика
# plt.rcParams["axes.labelsize"] = 11             # подписи осей
# plt.rcParams["xtick.labelsize"] = 10
# plt.rcParams["ytick.labelsize"] = 10
# plt.rcParams["legend.fontsize"] = 10

# # стиль графиков
# plt.style.use("default")

# %% [markdown]
# ### Warnings

# %% [markdown]
# import warnings
# warnings.warn("Это предупреждение!")

# %%
import warnings

# %%
warnings.warn("Это предупреждение!")

# %%
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %%
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Настройка темы ноутбука
# [ссылка](https://www.geeksforgeeks.org/how-to-change-the-theme-in-jupyter-notebook/)

# %%
# !pip install jupyterthemes

# %%
# !jt -l
# Out:
# Available Themes:
#    chesterish
#    grade3
#    gruvboxd
#    gruvboxl
#    monokai
#    oceans16
#    onedork
#    solarizedd
#    solarizedl

# %%
# !jt -t onedork

# %%
# !jt -r
# Out:
# Reset css and font defaults in:
# C:\Users\Dasha\.jupyter\custom &
# C:\Users\Dasha\AppData\Roaming\jupyter\nbextensions

# %% [markdown]
# ### Настройка вывода таблицы

# %%
df = pd.DataFrame(np.random.normal(size=(6,6)), columns=[x for x in "ABCDEF"])
df
# Out:
#    A         B         C         D         E         F
# 0 -0.455401  0.738232  0.613577 -0.241805 -1.032990  0.597450
# 1 -0.046104  1.073212  0.637897 -0.990623 -0.160910  2.358652
# 2 -0.357813 -0.821845  2.242303 -0.573997 -0.309299 -1.664333
# 3 -1.078366  1.369981  1.488207 -1.098480 -0.171816  0.675143
# 4  0.531509 -0.503595 -0.229827 -0.822044 -1.233877 -0.364358
# 5 -1.427461 -0.989053  0.180193 -0.441991  1.292754 -0.440226

# %%
def neg_red(x):
    return f"color: {'red' if x < 0 else 'green'}"

# df.style.applymap(neg_red)

df.style.applymap(lambda x: f"color: {'red' if x < 0 else 'gold'}")
# Out:
# <style type="text/css">
# #T_2619f_row0_col0, #T_2619f_row0_col2, #T_2619f_row1_col0, #T_2619f_row1_col1, #T_2619f_row1_col2, #T_2619f_row1_col4, #T_2619f_row1_col5, #T_2619f_row2_col0, #T_2619f_row2_col1, #T_2619f_row2_col2, #T_2619f_row2_col3, #T_2619f_row2_col4, #T_2619f_row3_col2, #T_2619f_row3_col3, #T_2619f_row3_col5, #T_2619f_row4_col1, #T_2619f_row4_col2, #T_2619f_row4_col4, #T_2619f_row5_col1, #T_2619f_row5_col3 {
#   color: gold;
# }
# #T_2619f_row0_col1, #T_2619f_row0_col3, #T_2619f_row0_col4, #T_2619f_row0_col5, #T_2619f_row1_col3, #T_2619f_row2_col5, #T_2619f_row3_col0, #T_2619f_row3_col1, #T_2619f_row3_col4, #T_2619f_row4_col0, #T_2619f_row4_col3, #T_2619f_row4_col5, #T_2619f_row5_col0, #T_2619f_row5_col2, #T_2619f_row5_col4, #T_2619f_row5_col5 {
#   color: red;
# }
# </style>
# <table id="T_2619f" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2619f_level0_col0" class="col_heading level0 col0" >A</th>
# ...

# %%
def gold_max(xs):
    m = xs.to_numpy().max()
    color = {True: "background-color: #c78f2e", False: ""}
    is_max = (xs == m).replace(color)
    return is_max

# %%
df.style.apply(gold_max, axis=0)
# Out:
# <style type="text/css">
# #T_56dc1_row0_col3, #T_56dc1_row1_col5, #T_56dc1_row2_col2, #T_56dc1_row3_col1, #T_56dc1_row4_col0, #T_56dc1_row5_col4 {
#   background-color: #c78f2e;
# }
# </style>
# <table id="T_56dc1" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_56dc1_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_56dc1_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_56dc1_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_56dc1_level0_col3" class="col_heading level0 col3" >D</th>
#       <th id="T_56dc1_level0_col4" class="col_heading level0 col4" >E</th>
#       <th id="T_56dc1_level0_col5" class="col_heading level0 col5" >F</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_56dc1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_56dc1_row0_col0" class="data row0 col0" >-0.455401</td>
# ...

# %%
df.style.background_gradient(cmap="viridis")
# Out:
# <style type="text/css">
# #T_fea5a_row0_col0 {
#   background-color: #21908d;
#   color: #f1f1f1;
# }
# #T_fea5a_row0_col1 {
#   background-color: #54c568;
#   color: #000000;
# }
# #T_fea5a_row0_col2 {
#   background-color: #306a8e;
#   color: #f1f1f1;
# }
# #T_fea5a_row0_col3, #T_fea5a_row1_col5, #T_fea5a_row2_col2, #T_fea5a_row3_col1, #T_fea5a_row4_col0, #T_fea5a_row5_col4 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_fea5a_row0_col4 {
#   background-color: #481d6f;
#   color: #f1f1f1;
# }
# #T_fea5a_row0_col5 {
#   background-color: #1f9f88;
#   color: #f1f1f1;
# }
# #T_fea5a_row1_col0 {
#   background-color: #46c06f;
#   color: #f1f1f1;
# }
# #T_fea5a_row1_col1 {
#   background-color: #aadc32;
#   color: #000000;
# }
# #T_fea5a_row1_col2 {
#   background-color: #2f6c8e;
#   color: #f1f1f1;
# }
# #T_fea5a_row1_col3 {
#   background-color: #472d7b;
#   color: #f1f1f1;
# }
# #T_fea5a_row1_col4 {
#   background-color: #277e8e;
#   color: #f1f1f1;
# }
# ...

# %%
df.abs().style.bar(align="left", width=90)
# Out:
# <style type="text/css">
# #T_ddab2_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 26.7%, transparent 26.7%);
# }
# #T_ddab2_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 24.4%, transparent 24.4%);
# }
# #T_ddab2_row0_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 18.9%, transparent 18.9%);
# }
# #T_ddab2_row0_col3, #T_ddab2_row1_col0, #T_ddab2_row1_col4, #T_ddab2_row4_col1, #T_ddab2_row4_col5, #T_ddab2_row5_col2 {
#   width: 10em;
# }
# #T_ddab2_row0_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 69.3%, transparent 69.3%);
# }
# #T_ddab2_row0_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 10.5%, transparent 10.5%);
# }
# #T_ddab2_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 59.2%, transparent 59.2%);
# }
# #T_ddab2_row1_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 20.0%, transparent 20.0%);
# }
# ...

# %%
head = {"selector": "th", "props": [("text-align", "center")]}
df.style.set_table_styles([head]).bar(align="mid", color=['red', 'green'], vmin=-3, vmax=3)
# Out:
# <style type="text/css">
# #T_31a72 th {
#   text-align: center;
# }
# #T_31a72_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 42.4%, red 42.4%, red 50.0%, transparent 50.0%);
# }
# #T_31a72_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, green 50.0%, green 62.3%, transparent 62.3%);
# }
# #T_31a72_row0_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, green 50.0%, green 60.2%, transparent 60.2%);
# }
# #T_31a72_row0_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 46.0%, red 46.0%, red 50.0%, transparent 50.0%);
# }
# #T_31a72_row0_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 32.8%, red 32.8%, red 50.0%, transparent 50.0%);
# }
# #T_31a72_row0_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, green 50.0%, green 60.0%, transparent 60.0%);
# }
# #T_31a72_row1_col0 {
#   width: 10em;
# ...

# %%
df.style.bar(align="mid", width=50).apply(gold_max, axis=None).applymap(neg_red)
# Out:
# <style type="text/css">
# #T_fa011_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 24.8%, #d65f5f 24.8%, #d65f5f 36.4%, transparent 36.4%);
#   color: red;
# }
# #T_fa011_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 21.0%, #d65f5f 21.0%, #d65f5f 36.6%, transparent 36.6%);
#   color: green;
# }
# #T_fa011_row0_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 4.6%, #d65f5f 4.6%, #d65f5f 17.1%, transparent 17.1%);
#   color: green;
# }
# #T_fa011_row0_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 39.0%, #d65f5f 39.0%, #d65f5f 50.0%, transparent 50.0%);
#   color: red;
# }
# #T_fa011_row0_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 4.0%, #d65f5f 4.0%, #d65f5f 24.4%, transparent 24.4%);
#   color: red;
# }
# #T_fa011_row0_col5 {
#   width: 10em;
# ...

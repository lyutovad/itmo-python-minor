# %% [markdown]
# # Занятие 8 — разминка
#
# Повторяем материал прошлого занятия: **выбросы и категориальные признаки**.
#
# Формат: выберите один правильный вариант.
# Ориентир: **10–15 минут**.

# %% [markdown]
# ## 1. Тип категориального признака
#
# Признак `room_type` принимает значения `Private room`, `Shared room`, `Entire home/apt`.
#
# Какой это тип категориального признака?
#
# A. Порядковый
# B. Номинальный
# C. Непрерывный числовой
# D. Временной
#
# **Ваш ответ:**

# %% [markdown]
# ## 2. Порядковая категория
#
# Какой признак является **порядковым**?
#
# A. Город: Москва, Казань, Томск
# B. Цвет товара: красный, синий, зелёный
# C. Размер: S, M, L, XL
# D. Тип оплаты: карта, наличные
#
# **Ваш ответ:**

# %% [markdown]
# ## 3. Кодирование номинального признака
#
# Есть признак `city` со значениями `Москва`, `Казань`, `Томск`. Естественного порядка нет.
#
# Что разумнее использовать для подготовки такого признака к ML?
#
# A. Назначить Москва=1, Казань=2, Томск=3
# B. One-Hot Encoding / `get_dummies`
# C. `StandardScaler`
# D. Z-score
#
# **Ваш ответ:**

# %% [markdown]
# ## 4. Что делает `get_dummies`?
#
# Что в основном делает `pd.get_dummies()`?
#
# A. Удаляет редкие категории
# B. Создаёт отдельные индикаторные столбцы для категорий
# C. Масштабирует числовые столбцы
# D. Ищет выбросы
#
# **Ваш ответ:**

# %% [markdown]
# ## 5. Выброс ≠ ошибка
#
# Boxplot показывает несколько очень больших значений цены.
#
# Какой вывод корректен?
#
# A. Их обязательно нужно удалить
# B. Это потенциальные выбросы, которые нужно сначала исследовать
# C. Их обязательно нужно заменить средним
# D. Boxplot доказывает, что данные ошибочны
#
# **Ваш ответ:**

# %% [markdown]
# ## 6. IQR
#
# Как обычно задаются границы выбросов методом IQR?
#
# A. `mean ± std`
# B. `Q1 - 1.5 * IQR` и `Q3 + 1.5 * IQR`
# C. `min` и `max`
# D. `median ± 1`
#
# **Ваш ответ:**

# %% [markdown]
# ## 7. Z-score
#
# Что показывает Z-score отдельного наблюдения?
#
# A. Сколько категорий есть в столбце
# B. Насколько значение удалено от среднего в единицах стандартного отклонения
# C. Долю пропусков
# D. Порядковый номер строки
#
# **Ваш ответ:**

# %% [markdown]
# ## 8. Z-score и сильная асимметрия
#
# В столбце очень асимметричное распределение и есть экстремально большие значения.
#
# Какое утверждение разумнее?
#
# A. Z-score всегда идеально подходит
# B. IQR часто оказывается более устойчивым, чем правило на среднем и стандартном отклонении
# C. Выбросы можно искать только графиком
# D. Нужно обязательно удалить половину данных
#
# **Ваш ответ:**

# %% [markdown]
# ## 9. Удаление или clipping
#
# Что означает **clipping** выбросов?
#
# A. Удалить строки с выбросами
# B. Ограничить слишком маленькие и большие значения заданными границами
# C. Заменить весь столбец медианой
# D. Перевести столбец в строку
#
# **Ваш ответ:**

# %% [markdown]
# ## 10. Удаление строк
#
# Есть булева маска `outlier_mask`, где `True` означает выброс.
#
# Как оставить только строки **без** выбросов?
#
# A. `df[outlier_mask]`
# B. `df[~outlier_mask]`
# C. `df.dropna()`
# D. `df.sort_values()`
#
# **Ваш ответ:**

# %% [markdown]
# ## 11. Изменить только часть значений
#
# Нужно заменить значения `price` выше верхней границы `upper` на `upper`.
#
# Какой вариант лучше отражает такую операцию?
#
# A. `df.loc[df["price"] > upper, "price"] = upper`
# B. `df["price"] = upper`
# C. `df.drop("price")`
# D. `df.iloc[0] = upper`
#
# **Ваш ответ:**

# %% [markdown]
# ## 12. Как сначала изучить категории?
#
# Перед кодированием категориального признака что полезнее сделать в первую очередь?
#
# A. Сразу применить `StandardScaler`
# B. Посмотреть `value_counts()`, `unique()` / `nunique()`
# C. Удалить столбец
# D. Заменить категории случайными числами
#
# **Ваш ответ:**

# %% [markdown]
# ## После теста
#
# Попробуйте без кода сформулировать:
#
# 1. Чем номинальная категория отличается от порядковой?
# 2. Почему не каждый выброс нужно удалять?
# 3. Чем удаление выбросов отличается от clipping?
# 4. В каких случаях IQR может быть удобнее Z-score?
